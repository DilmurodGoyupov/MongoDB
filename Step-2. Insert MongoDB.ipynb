# %% [markdown]
# # <center> <h1>  💾 🧑‍💻 🗃️

# %% [markdown]
# <center>
#
# # ![MongoDB_Logo.jpg](attachment:837e2e12-1087-41e4-af57-b5c7499fb724.jpg)

# %%
import pymongo

# %%
# 1 - bo'lib saytdan Cluster ga ulanamiz
client = pymongo.MongoClient("mongodb+srv://userName:password@cluster0.0ib3cab.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
#client
# userName - o'zingizning username ni yozasiz
# password - o'zingizning parolni yozasiz

# %% [markdown]
# # <center>  1-qadam. DataBase yaratish

# %%
# Clusterda users degan DataBase yaratib olamiz
db = client.users
#db

# %% [markdown]
# # <center>  Collection yaratish

# %%
# users degan database da royxat nomli kolleksiya yaratamiz
kolleksiya = db.royxat
#kolleksiya

# %% [markdown]
# ## <center> Pastdagi rasmga e'tibor bersaningiz. Bizda hech qanday Database va Kolleksiya yaratilmagan. Chunki biz Database va Kollekiya yaratganimizda ichiga Hujjatlarni ham qo'shishimiz kerak aks holda ular qo'shilmaydi
# <center>
#
# # ![изображение.png](attachment:cde3263d-723a-4537-9f5a-99d9008f0c41.png)

# %% [markdown]
# # <center> Kolleksiyaga hujjat(dokument) qo'shish. 1 tadan

# %%
kolleksiya.insert_one({"_id":1, "suname":"Jafarov", "name":"Elbek", "age":58, "phone_number":"+99893 1234567"})
kolleksiya.insert_one({"_id":2, "suname":"Yuldoshev", "name":"Zohid", "age":57, "phone_number":"+99893 9876543"})
kolleksiya.insert_one({"_id":3, "suname":"Sirojiddinova", "name":"Asal", "age":30, "phone_number":"+99899 5463217"})
kolleksiya.insert_one({"_id":4, "suname":"Yuldoshev", "name":"Kamron", "age":28, "phone_number":"+99890 6932541"})
kolleksiya.insert_one({"_id":5, "suname":"Yuldosheva", "name":"Shaxzoda", "age":24, "phone_number":"+99899 2593614"})
kolleksiya.insert_one({"_id":6, "suname":"Jafarov", "name":"Malik", "age":22, "phone_number":"+99899 1482536"})
kolleksiya.insert_one({"_id":7, "suname":"Jafarov", "name":"Xushnud", "age":26, "phone_number":"+99899 9623514"})
kolleksiya.insert_one({"_id":8, "suname":"Yuldoshev", "name":"Bobur", "age":28, "phone_number":"+99894 2589641"})
kolleksiya.insert_one({"_id":9, "suname":"Sirojiddinov", "name":"Alibek", "age":26, "phone_number":"+99890 4269578"})

kolleksiya.insert_one({"_id":10, "suname":"Jafarov", "name":"Elbek", "age":58, "phone_number":"+99893 1234567"})
kolleksiya.insert_one({"_id":11, "suname":"Yuldoshev", "name":"Zohid", "age":57, "phone_number":"+99893 9876543"})
kolleksiya.insert_one({"_id":12, "suname":"Sirojiddinova", "name":"Asal", "age":30, "phone_number":"+99899 5463217"})
kolleksiya.insert_one({"_id":13, "suname":"Yuldoshev", "name":"Kamron", "age":28, "phone_number":"+99890 6932541"})
kolleksiya.insert_one({"_id":14, "suname":"Yuldosheva", "name":"Shaxzoda", "age":24, "phone_number":"+99899 2593614"})
kolleksiya.insert_one({"_id":15, "suname":"Jafarov", "name":"Malik", "age":22, "phone_number":"+99899 1482536"})
kolleksiya.insert_one({"_id":16, "suname":"Jafarov", "name":"Xushnud", "age":26, "phone_number":"+99899 9623514"})
kolleksiya.insert_one({"_id":17, "suname":"Yuldoshev", "name":"Bobur", "age":28, "phone_number":"+99894 2589641"})
kolleksiya.insert_one({"_id":18, "suname":"Sirojiddinov", "name":"Alibek", "age":26, "phone_number":"+99890 4269578"})
# Out:
# InsertOneResult(18, acknowledged=True)

# %% [markdown]
# <ceneter>
#
# # ![изображение.png](attachment:794dabba-0fa8-46d6-8b88-4de9dc8f64d7.png)

# %%
kolleksiya.insert_one({"_id":1, "name":"Dilshod"})
# xatolik chiqadi
# chunki bizda _id unikal hisoblanadi, shuning uchun bir xil _id ga ega bo'lgan dokument qo'sha olmaymiz
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 kolleksiya.insert_one({"_id":1, "name":"Dilshod"})
#
# File D:\IT\Python\YOLO\yolo\lib\site-packages\pymongo\collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
#     678     write_concern.acknowledged,
#     679 )
#
# ...

# %%
kolleksiya.insert_one({"suname":"Bozorboyev", "name":"Dilshod", "age":50, "phone_number":"+99899 1286543"})
# agar document qo'shish paytida _id ni ko'rsatmasak u avtomatik qo'shiladi, lekin u id juda ham uzun 
# bo'ladi va uni ishlatish qiyin, shuning uchun id ni o'zimiz ko'rsatganimiz maqul
# Pastga qarang
# ObjectId('66375131c8bdeb09246a0abd')
# Out:
# InsertOneResult(ObjectId('66375131c8bdeb09246a0abd'), acknowledged=True)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:367eb61a-6f32-415e-9189-57e84a24fb24.png)

# %% [markdown]
# ## Bir nechta dokument qo'shish

# %%
data = [
    {
        "_id":19,
        "suname":"Jafarov",
        "name":"Elbek",
        "age":29,
        "phone_number": "+99893 1284521"
    },
    {
        "_id":20,
        "suname":"Yuldoshev",
        "name":"Zohid",
        "age":57,
        "phone_number": "+99890 9876543"
    },
    {
        "_id":21,
        "suname":"Asilbekova",
        "name":"Diyora",
        "age":22,
        "phone_number": "+9988 5552296"
    },
    {
        "_id":22,
        "suname":"Gafurova",
        "name":"Dilnoza",
        "age":54,
        "phone_number": "+99891 2541452"
    },
    {
        "_id":23,
        "suname":"Chingizov",
        "name":"Elshod",
        "age":32,
        "phone_number": "+99895 4569827"
    }
]

kolleksiya.insert_many(data)
# Out:
# InsertManyResult([19, 20, 21, 22, 23], acknowledged=True)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:4f643677-f976-437a-9cd0-7a4cf88ee808.png)

# %% [markdown]
# ## Endi biz royxat degan kolleksiyamizga boshqa dokumentlarni qo'shamiz. Oddiy SQL jadvallardan bizning kolleksiyamizning asosiy farqi shundaki biz unga har xil turdagi documentlarni qo'sha olamiz

# %%
kolleksiya.insert_one({"_id":24, "laptop_model":"Hp Pavilion Gaming", "cpu":"Amd Ryzen", "gpu":"GeForce GTX 1650 Ti"})
kolleksiya.insert_one({"_id":25, "phone_model":"iphone 15", "cpu":"16 Bionic", "dsplay":"Liquid Retina XDR"})
kolleksiya.insert_one({"_id":26, "car_model":"Mersedes Benz GLA", "engine_capacity":1595, "transmission":"Manual transmission", "Number_of_seats":5})
# Out:
# InsertOneResult(26, acknowledged=True)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:51ba831d-1850-459b-b370-142d5553cd01.png)

# %% [markdown]
# # <center> <h1> 👨‍💻   🚀
