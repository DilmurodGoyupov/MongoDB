# %% [markdown]
# # <center> <h1>  💾 🧑‍💻 🗃️

# %% [markdown]
# <center>
#
# # ![MongoDB_Logo.jpg](attachment:9d200642-ec0c-42e8-a9cc-f45fb2185978.jpg)

# %%
import pymongo

# %%
# 1 - bo'lib saytdan Cluster ga ulanamiz
client = pymongo.MongoClient("mongodb+srv://userName:password@cluster0.0ib3cab.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
#client
# userName - o'zingizning username ni yozasiz
# password -  o'zingizning parolni yozasiz

# %%
# database
db = client.test
#db

# %%
kolleksiya = db.number_password
#kolleksiya

# %%
# kolleksiyamizga dokumnet qoshib olamiz
for i in range(20):
    kolleksiya.insert_one({"_id":i, "name":f"test{i}", "password":123456789})

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 0, 'name': 'test0', 'password': 123456789}
# {'_id': 1, 'name': 'test1', 'password': 123456789}
# {'_id': 2, 'name': 'test2', 'password': 123456789}
# {'_id': 3, 'name': 'test3', 'password': 123456789}
# {'_id': 4, 'name': 'test4', 'password': 123456789}
# {'_id': 5, 'name': 'test5', 'password': 123456789}
# {'_id': 6, 'name': 'test6', 'password': 123456789}
# {'_id': 7, 'name': 'test7', 'password': 123456789}
# {'_id': 8, 'name': 'test8', 'password': 123456789}
# {'_id': 9, 'name': 'test9', 'password': 123456789}
# {'_id': 10, 'name': 'test10', 'password': 123456789}
# {'_id': 11, 'name': 'test11', 'password': 123456789}
# {'_id': 12, 'name': 'test12', 'password': 123456789}
# {'_id': 13, 'name': 'test13', 'password': 123456789}
# {'_id': 14, 'name': 'test14', 'password': 123456789}
# {'_id': 15, 'name': 'test15', 'password': 123456789}
# {'_id': 16, 'name': 'test16', 'password': 123456789}
# {'_id': 17, 'name': 'test17', 'password': 123456789}
# ...

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:d0d180d1-ebfa-4530-9c0e-427a2929e695.png)

# %% [markdown]
# ## <center> Update

# %%
#dokumentni update qilish
current = {"name":"test3"} # bu biz alishtirmoqchi bo'lgan element
new_data = {"$set":{"name":"new_test3"}} # yangi element

kolleksiya.update_one(current, new_data)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714915510, 1), 't': 12}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714915510, 1), 'signature': {'hash': b'\xd5\x8a\xaf\x93\xf6X\xd2\xfc\x0cyM:\n\x04\xf91G\xddEN', 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714915510, 1), 'updatedExisting': True}, acknowledged=True)

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 0, 'name': 'test0', 'password': 123456789}
# {'_id': 1, 'name': 'test1', 'password': 123456789}
# {'_id': 2, 'name': 'test2', 'password': 123456789}
# {'_id': 3, 'name': 'new_test3', 'password': 123456789}
# {'_id': 4, 'name': 'test4', 'password': 123456789}
# {'_id': 5, 'name': 'test5', 'password': 123456789}
# {'_id': 6, 'name': 'test6', 'password': 123456789}
# {'_id': 7, 'name': 'test7', 'password': 123456789}
# {'_id': 8, 'name': 'test8', 'password': 123456789}
# {'_id': 9, 'name': 'test9', 'password': 123456789}
# {'_id': 10, 'name': 'test10', 'password': 123456789}
# {'_id': 11, 'name': 'test11', 'password': 123456789}
# {'_id': 12, 'name': 'test12', 'password': 123456789}
# {'_id': 13, 'name': 'test13', 'password': 123456789}
# {'_id': 14, 'name': 'test14', 'password': 123456789}
# {'_id': 15, 'name': 'test15', 'password': 123456789}
# {'_id': 16, 'name': 'test16', 'password': 123456789}
# {'_id': 17, 'name': 'test17', 'password': 123456789}
# ...

# %%
# Biz ismni topib lekin passwordni o'zgartirsak ham bo'ladi

current = {"name":"test10"}
new_data = {"$set":{"password":987654321}}

kolleksiya.update_one(current, new_data)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714915514, 2), 't': 12}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714915514, 2), 'signature': {'hash': b'\xf9\xa5\x01b\xf1\x85\x12\xa2wo\xe6\xddY\x8e\x1b\x08\n&\xe9\x9a', 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714915514, 2), 'updatedExisting': True}, acknowledged=True)

# %%
for value in kolleksiya.find():
    print(value)
# test10 ni topdik va uning passwordini o'zgartirdik
# Out:
# {'_id': 0, 'name': 'test0', 'password': 123456789}
# {'_id': 1, 'name': 'test1', 'password': 123456789}
# {'_id': 2, 'name': 'test2', 'password': 123456789}
# {'_id': 3, 'name': 'new_test3', 'password': 123456789}
# {'_id': 4, 'name': 'test4', 'password': 123456789}
# {'_id': 5, 'name': 'test5', 'password': 123456789}
# {'_id': 6, 'name': 'test6', 'password': 123456789}
# {'_id': 7, 'name': 'test7', 'password': 123456789}
# {'_id': 8, 'name': 'test8', 'password': 123456789}
# {'_id': 9, 'name': 'test9', 'password': 123456789}
# {'_id': 10, 'name': 'test10', 'password': 987654321}
# {'_id': 11, 'name': 'test11', 'password': 123456789}
# {'_id': 12, 'name': 'test12', 'password': 123456789}
# {'_id': 13, 'name': 'test13', 'password': 123456789}
# {'_id': 14, 'name': 'test14', 'password': 123456789}
# {'_id': 15, 'name': 'test15', 'password': 123456789}
# {'_id': 16, 'name': 'test16', 'password': 123456789}
# {'_id': 17, 'name': 'test17', 'password': 123456789}
# ...

# %%
kolleksiya.insert_one({'_id': 20, 'name': 'Alijon', 'password': 258369147})
kolleksiya.insert_one({'_id': 21, 'name': 'Shuxrat', 'password': 741852963})
# yangi 2 ta dokument qo'shib oldik
# Out:
# InsertOneResult(21, acknowledged=True)

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 0, 'name': 'test0', 'password': 123456789}
# {'_id': 1, 'name': 'test1', 'password': 123456789}
# {'_id': 2, 'name': 'test2', 'password': 123456789}
# {'_id': 3, 'name': 'new_test3', 'password': 123456789}
# {'_id': 4, 'name': 'test4', 'password': 123456789}
# {'_id': 5, 'name': 'test5', 'password': 123456789}
# {'_id': 6, 'name': 'test6', 'password': 123456789}
# {'_id': 7, 'name': 'test7', 'password': 123456789}
# {'_id': 8, 'name': 'test8', 'password': 123456789}
# {'_id': 9, 'name': 'test9', 'password': 123456789}
# {'_id': 10, 'name': 'test10', 'password': 987654321}
# {'_id': 11, 'name': 'test11', 'password': 123456789}
# {'_id': 12, 'name': 'test12', 'password': 123456789}
# {'_id': 13, 'name': 'test13', 'password': 123456789}
# {'_id': 14, 'name': 'test14', 'password': 123456789}
# {'_id': 15, 'name': 'test15', 'password': 123456789}
# {'_id': 16, 'name': 'test16', 'password': 123456789}
# {'_id': 17, 'name': 'test17', 'password': 123456789}
# ...

# %%
# regex orqali qidirishni amalga ishirib ham almashtirsak bo'ladi 
current = {"name":{"$regex":"test"}}
new_data = {"$set":{"password":987654321}}

kolleksiya.update_many(current, new_data)
# hamma test dan boshanadigan ismlarni passwordini 987654321 qilib o'zgartirdik
# Out:
# UpdateResult({'n': 20, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714915527, 20), 't': 12}, 'nModified': 19, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714915527, 20), 'signature': {'hash': b'6|\xeb\xf0\x8dPM\xb2\xa9\x1c%q\x07\xea\x93V\xa1\xa0\x1b\xf8', 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714915527, 20), 'updatedExisting': True}, acknowledged=True)

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 0, 'name': 'test0', 'password': 987654321}
# {'_id': 1, 'name': 'test1', 'password': 987654321}
# {'_id': 2, 'name': 'test2', 'password': 987654321}
# {'_id': 3, 'name': 'new_test3', 'password': 987654321}
# {'_id': 4, 'name': 'test4', 'password': 987654321}
# {'_id': 5, 'name': 'test5', 'password': 987654321}
# {'_id': 6, 'name': 'test6', 'password': 987654321}
# {'_id': 7, 'name': 'test7', 'password': 987654321}
# {'_id': 8, 'name': 'test8', 'password': 987654321}
# {'_id': 9, 'name': 'test9', 'password': 987654321}
# {'_id': 10, 'name': 'test10', 'password': 987654321}
# {'_id': 11, 'name': 'test11', 'password': 987654321}
# {'_id': 12, 'name': 'test12', 'password': 987654321}
# {'_id': 13, 'name': 'test13', 'password': 987654321}
# {'_id': 14, 'name': 'test14', 'password': 987654321}
# {'_id': 15, 'name': 'test15', 'password': 987654321}
# {'_id': 16, 'name': 'test16', 'password': 987654321}
# {'_id': 17, 'name': 'test17', 'password': 987654321}
# ...

# %%
# Dokumentda yangi elemnt qo'shamiz(update)
current = {"name":"test1"}
new_data = {"$set":{"balance":200}}

kolleksiya.update_one(current, new_data)
# test1 ga yangi balance nomi elemnt qo'shdik va uning qiymatini 200 qilib belgiladik
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714915543, 4), 't': 12}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714915543, 4), 'signature': {'hash': b'A\xfc2E\xce\x93\xcc\x97&\xb1\xc3J\xd6\xa6i\xa8Ri\xb9q', 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714915543, 4), 'updatedExisting': True}, acknowledged=True)

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 0, 'name': 'test0', 'password': 987654321}
# {'_id': 1, 'name': 'test1', 'password': 987654321, 'balance': 200}
# {'_id': 2, 'name': 'test2', 'password': 987654321}
# {'_id': 3, 'name': 'new_test3', 'password': 987654321}
# {'_id': 4, 'name': 'test4', 'password': 987654321}
# {'_id': 5, 'name': 'test5', 'password': 987654321}
# {'_id': 6, 'name': 'test6', 'password': 987654321}
# {'_id': 7, 'name': 'test7', 'password': 987654321}
# {'_id': 8, 'name': 'test8', 'password': 987654321}
# {'_id': 9, 'name': 'test9', 'password': 987654321}
# {'_id': 10, 'name': 'test10', 'password': 987654321}
# {'_id': 11, 'name': 'test11', 'password': 987654321}
# {'_id': 12, 'name': 'test12', 'password': 987654321}
# {'_id': 13, 'name': 'test13', 'password': 987654321}
# {'_id': 14, 'name': 'test14', 'password': 987654321}
# {'_id': 15, 'name': 'test15', 'password': 987654321}
# {'_id': 16, 'name': 'test16', 'password': 987654321}
# {'_id': 17, 'name': 'test17', 'password': 987654321}
# ...

# %% [markdown]
# ## <center> Increment(decrement) $inc

# %% [markdown]
# ## Rasmga e'tibor bering test1 da bizda balance bor va uing qiymati 200 ga teng Biz bilan Increment (decrement) amalni amalaga oshirsak boladi. yani qo'shish yoki ayirish
#
# <center>
#
# # ![изображение.png](attachment:08c0209e-53c7-4df0-bd83-2e14de88ddb5.png)

# %%
current = {"_id":1}
new_data = {"$inc":{"balance":-100}}
kolleksiya.update_one(current, new_data)
# 200-100=100 qiymat bo'ladi
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714915724, 1), 't': 12}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714915724, 1), 'signature': {'hash': b"\xcc\x81\xec\x92\x10\xbe\x90\x94R\x06\xd8'E\xb9T5\xe9\x139^", 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714915724, 1), 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:bc6e0203-79b3-4625-976c-354e45a70392.png)

# %%
current = {"_id":1}
new_data = {"$inc":{"balance":+1000}}

kolleksiya.update_one(current, new_data)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714915844, 2), 't': 12}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714915844, 2), 'signature': {'hash': b"\xf1\xf4\\\xad\xf7'\xabPS\xab>\x93\xd2\xeeir\xd89\x82\x89", 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714915844, 2), 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:32d64563-6e3d-41e7-b9d5-b81f0853c7d0.png)

# %%
# Keling hamma dokumentga yosh degan element qo'shib olamiz
for i in range(20):
    current = {"_id":i}
    new_data = {"$set":{"age":i}}
    kolleksiya.update_one(current, new_data)

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 0, 'name': 'test0', 'password': 987654321, 'age': 0}
# {'_id': 1, 'name': 'test1', 'password': 987654321, 'balance': 1100, 'age': 1}
# {'_id': 2, 'name': 'test2', 'password': 987654321, 'age': 2}
# {'_id': 3, 'name': 'new_test3', 'password': 987654321, 'age': 3}
# {'_id': 4, 'name': 'test4', 'password': 987654321, 'age': 4}
# {'_id': 5, 'name': 'test5', 'password': 987654321, 'age': 5}
# {'_id': 6, 'name': 'test6', 'password': 987654321, 'age': 6}
# {'_id': 7, 'name': 'test7', 'password': 987654321, 'age': 7}
# {'_id': 8, 'name': 'test8', 'password': 987654321, 'age': 8}
# {'_id': 9, 'name': 'test9', 'password': 987654321, 'age': 9}
# {'_id': 10, 'name': 'test10', 'password': 987654321, 'age': 10}
# {'_id': 11, 'name': 'test11', 'password': 987654321, 'age': 11}
# {'_id': 12, 'name': 'test12', 'password': 987654321, 'age': 12}
# {'_id': 13, 'name': 'test13', 'password': 987654321, 'age': 13}
# {'_id': 14, 'name': 'test14', 'password': 987654321, 'age': 14}
# ...

# %%
# Endi $inc orqali hamma dokumentdagi yoshlarni 1 yoshga oshiramiz
kolleksiya.update_many({"age":{"$exists":True}}, # $exists bu dokumentda age elementi bor yo'qligini tekshiradi
                       {"$inc":{"age":+1}})
# Out:
# UpdateResult({'n': 20, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714916237, 23), 't': 12}, 'nModified': 20, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714916237, 23), 'signature': {'hash': b'\x9f:9\x01[\xa1\x06\xe5C\xf0\x05\x8e\x90\xd1\x82\xb7P3\xbf)', 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714916237, 23), 'updatedExisting': True}, acknowledged=True)

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 0, 'name': 'test0', 'password': 987654321, 'age': 1}
# {'_id': 1, 'name': 'test1', 'password': 987654321, 'balance': 1100, 'age': 2}
# {'_id': 2, 'name': 'test2', 'password': 987654321, 'age': 3}
# {'_id': 3, 'name': 'new_test3', 'password': 987654321, 'age': 4}
# {'_id': 4, 'name': 'test4', 'password': 987654321, 'age': 5}
# {'_id': 5, 'name': 'test5', 'password': 987654321, 'age': 6}
# {'_id': 6, 'name': 'test6', 'password': 987654321, 'age': 7}
# {'_id': 7, 'name': 'test7', 'password': 987654321, 'age': 8}
# {'_id': 8, 'name': 'test8', 'password': 987654321, 'age': 9}
# {'_id': 9, 'name': 'test9', 'password': 987654321, 'age': 10}
# {'_id': 10, 'name': 'test10', 'password': 987654321, 'age': 11}
# {'_id': 11, 'name': 'test11', 'password': 987654321, 'age': 12}
# {'_id': 12, 'name': 'test12', 'password': 987654321, 'age': 13}
# {'_id': 13, 'name': 'test13', 'password': 987654321, 'age': 14}
# {'_id': 14, 'name': 'test14', 'password': 987654321, 'age': 15}
# ...

# %% [markdown]
# ## <center> $existis

# %%
for value in kolleksiya.find({"age":{"$exists":True}}): # $exists faqat Boolean qiymatni qabul qiladi, ya'ni True yoki False
    print(value)
# Faqat age elementi bor dokumentlarni chiqaradi
# Out:
# {'_id': 0, 'name': 'test0', 'password': 987654321, 'age': 1}
# {'_id': 1, 'name': 'test1', 'password': 987654321, 'balance': 1100, 'age': 2}
# {'_id': 2, 'name': 'test2', 'password': 987654321, 'age': 3}
# {'_id': 3, 'name': 'new_test3', 'password': 987654321, 'age': 4}
# {'_id': 4, 'name': 'test4', 'password': 987654321, 'age': 5}
# {'_id': 5, 'name': 'test5', 'password': 987654321, 'age': 6}
# {'_id': 6, 'name': 'test6', 'password': 987654321, 'age': 7}
# {'_id': 7, 'name': 'test7', 'password': 987654321, 'age': 8}
# {'_id': 8, 'name': 'test8', 'password': 987654321, 'age': 9}
# {'_id': 9, 'name': 'test9', 'password': 987654321, 'age': 10}
# {'_id': 10, 'name': 'test10', 'password': 987654321, 'age': 11}
# {'_id': 11, 'name': 'test11', 'password': 987654321, 'age': 12}
# {'_id': 12, 'name': 'test12', 'password': 987654321, 'age': 13}
# {'_id': 13, 'name': 'test13', 'password': 987654321, 'age': 14}
# {'_id': 14, 'name': 'test14', 'password': 987654321, 'age': 15}
# ...

# %% [markdown]
# # <center> <h1> 👨‍💻   🚀
