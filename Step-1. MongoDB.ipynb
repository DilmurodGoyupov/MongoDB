# %% [markdown]
# # <center> <h1>  💾 🧑‍💻 🗃️

# %% [markdown]
# <center>
#
# # ![MongoDB_Logo.jpg](attachment:b318912d-62e5-47c2-a4c5-2f9a0c874e55.jpg)

# %% [markdown]
# # <center> MongoDB - bu hujjatlar bilan ishlashga yo'naltirilgan ma'lumotlar bazasini boshqarish tizimi, ya'ni bizda jadvallar bo'lishi shart emas. MongoDB NoSQL malumotlar bazasi turiga kiradi, u JSONga o'xshash hujjatlar va ma'lumotlar bazasi sxemasidan foydalanadi, bu shuni anglatadiki biz MongoDB da ishlash uchun SQL so'rovlarini bilishimiz shart emas. MongoDB C++ tilida yozilgan. MongoDB da Odatiy SQL dagi jadvallar yo'q, aksincha unda kolleksiyalar bor. Kolleksiyalar, SQL dagi jadvallarning analogi hisoblanadi, lekin ular jadvallarga o'xshab aniq bir strukturaga ega emas.
#
#
# <center>
#
#
# # MongoDB Ierararxiyasi
# 1. Klaster(Cluster). Bu MongoDB ierarxiyasining eng yuqori darajasi. Klaster ma'lumotlarni saqlash va qayta ishlash uchun birgalikda ishlaydigan bir nechta ma'lumotlar bazasidan iborat.
# 2. Ma'lumotlar bazasi(DataBase): Har bir MongoDB klasterida bir nechta ma'lumotlar bazalari bo'lishi mumkin. Ma'lumotlar bazasi to'plamlar va indekslar uchun mantiqiy konteynerdir. Ma'lumotlar bazasi ichida ma'lumotlar, shuningdek, foydalanuvchilar, kirish huquqlari va konfiguratsiya parametrlari kabi meta ma'lumotlar saqlanadi.
# 3.  To'plam(Collection): To'plam ma'lumotlar bazasida joylashgan va hujjatlar uchun konteynerdir. Bu so'rovlar ishlashini yaxshilash uchun indekslanishi mumkin bo'lgan tartiblangan hujjatlar to'plamini ifodalaydi. To'plam(Collection) turli tuzilmalarning hujjatlarini o'z ichiga olishi mumkin, shuningdek, ma'lumotlarni oddiy va samarali saqlash va tashkil etishni ta'minlaydi.
# 4.  Hujjat(Document): Hujjat to'plamda joylashgan va MongoDBda ma'lumotlar birligini ifodalaydi. U kalit-qiymat juftliklaridan iborat bo'lib, bu erda kalitlar maydonlarning nomlari va qiymatlar ma'lumotlarning o'zi. MongoDB-dagi hujjatlar turli tuzilmalarga ega bo'lishi mumkin va ularning formati qat'iy sxemani talab qilmaydi, bu esa ma'lumotlar bazasini yanada moslashuvchan va masshtabli qiladi.

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-05-05 114616.png](attachment:405c7839-0c7c-464a-bc7a-388370b3c7c3.png)

# %% [markdown]
# # <center> 1 - qadam. MongoDB saytiga kiramiz va ro'yxatdan o'tamiz.

# %% [markdown]
# # <center> 1.1 - qadam. New Project yaratib olamiz
# <center>
#
# # ![Screenshot 2024-05-05 102740.png](attachment:583268e9-7510-44b7-beeb-fa54813c4d09.png)

# %% [markdown]
# # <center> 1.2 - qadam. Project ga nom beramiz va Next ni bosamiz(Ixtiyoriy ravishda tag qo'shsak ham bo'ladi)
#
# <center>
#
# # ![Screenshot 2024-05-05 103507.png](attachment:8f34bd97-b6fc-4ad5-b125-2ee29ba6071a.png)

# %% [markdown]
# # <center> 1.3 - qadam.  Kimlarni Projectga qo'shishimizni ko'rsatishimiz mumkin.
#
# <center>
#
# # ![Screenshot 2024-05-05 103618.png](attachment:e176e509-3936-48f7-aa05-0f1b62d97eed.png)

# %% [markdown]
# # <center> 1.4 - qadam. Create
#
# <center>
#
# # ![изображение.png](attachment:6fd27b67-daaf-487d-87d0-8c0a49b6ed54.png)

# %% [markdown]
# # <center> 1.5 - qadam. O'zimizga kerakli ta'rifni tanlaymiz(Biz Free yani tekin tarifni tanladik) va Cluster nomini kiritamiz. Create deployment
#
# <center>
#
# # ![Screenshot 2024-05-05 104410.png](attachment:122dcecb-6a3c-4e59-a7c3-335170ee9a1a.png)

# %% [markdown]
# # <center> 1.6 - qadam.
# * 1-bizga ulanish uchun Ip manzil beriladi.
# * 2-bizning userName
# * 3-bizning parol
#
# `Bular orqali biz bazamizga ulanamiz`
#
# <center>
#
# # ![Screenshot 2024-05-05 105042.png](attachment:ce2cffac-ba05-43af-8264-621a94d6c3a3.png)

# %% [markdown]
# # <center> 1.7 - qadam. Clusterga ulanamiz
#
# <center>
#
# # ![Screenshot 2024-05-05 105923.png](attachment:8967f3b0-40ca-4934-bbb3-14744195bae1.png)

# %% [markdown]
# # <center> 1.8.1- qadam.
#
# * 1. Dasturlash tilini tanlaymiz.
#   2. Copy qilingan kodni o'rnatamiz
#   3. Copy qilingan kod orqali Clusterga ulanamiz(hamma o'zining userName va passwordni kiritadi)
#   4. Ulanamiz
#
# <center>
#
# # ![Screenshot 2024-05-05 110740.png](attachment:b4a558bd-bd6a-49b9-acb7-6ba47de861da.png)

# %% [markdown]
# # <center> 1.8.2 - qadam.

# %%
# !python -m pip install "pymongo[srv]"

# %% [markdown]
# # <center>  Connect

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://userName:password@cluster0.0ib3cab.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
# client
# userName - o'zingizning username ni yozasiz
# password - o'zingizning parolni yozasiz

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-05-05 112554.png](attachment:f96fb3b5-cbd3-4d0e-b987-71f3286e829f.png)

# %% [markdown]
# # <center> Clusterda avtomatik ravishda sample_mflix database yaratiladi, uning ichida bir nechta kolleksiyakar bo'ladi va kolleksiyaning ichida hujjatlar bo'ladi.
#
# <center>
#
# # ![изображение.png](attachment:6a5c1694-ba55-4253-841e-44cd6eec4919.png)

# %% [markdown]
# # <center> <h1> 👨‍💻   🚀
