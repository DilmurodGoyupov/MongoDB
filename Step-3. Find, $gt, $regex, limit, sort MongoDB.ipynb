# %% [markdown]
# # <center> <h1>  💾 🧑‍💻 🗃️

# %% [markdown]
# <center>
#
# # ![MongoDB_Logo.jpg](attachment:78dc3c58-0e34-46b6-a6e1-7a147598645e.jpg)

# %%
import pymongo

# %%
# 1 - bo'lib saytdan Cluster ga ulanamiz
client = pymongo.MongoClient("mongodb+srv://userName:password@cluster0.0ib3cab.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
#client
# userName - o'zingizning username ni yozasiz
# password - o'zingizning parolni yozasiz

# %%
db = client.users
#db

# %%
kolleksiya = db.royxat
#kolleksiya

# %% [markdown]
# # <center> Find - Qidirish

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 1, 'suname': 'Jafarov', 'name': 'Elbek', 'age': 58, 'phone_number': '+99893 1234567'}
# {'_id': 2, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 3, 'suname': 'Sirojiddinova', 'name': 'Asal', 'age': 30, 'phone_number': '+99899 5463217'}
# {'_id': 4, 'suname': 'Yuldoshev', 'name': 'Kamron', 'age': 28, 'phone_number': '+99890 6932541'}
# {'_id': 5, 'suname': 'Yuldosheva', 'name': 'Shaxzoda', 'age': 24, 'phone_number': '+99899 2593614'}
# {'_id': 6, 'suname': 'Jafarov', 'name': 'Malik', 'age': 22, 'phone_number': '+99899 1482536'}
# {'_id': 7, 'suname': 'Jafarov', 'name': 'Xushnud', 'age': 26, 'phone_number': '+99899 9623514'}
# {'_id': 8, 'suname': 'Yuldoshev', 'name': 'Bobur', 'age': 28, 'phone_number': '+99894 2589641'}
# {'_id': 9, 'suname': 'Sirojiddinov', 'name': 'Alibek', 'age': 26, 'phone_number': '+99890 4269578'}
# {'_id': 10, 'suname': 'Jafarov', 'name': 'Elbek', 'age': 58, 'phone_number': '+99893 1234567'}
# ...

# %% [markdown]
# # <center> Aniq bir kalit bo'yicha qidirish

# %%
query = {"name":"Zohid"}

for value in kolleksiya.find(query):
    print(value)
# Out:
# {'_id': 2, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 11, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 20, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99890 9876543'}

# %%
query = {"name":"Elbek"}

for value in kolleksiya.find(query, {"_id":0}): # {"_id":0} orqali biz print() da _id ni ko'rsatma deb ko'rsatishimiz mumkin. Bu faqat _id uchun ishlaydi
    print(value)
# Out:
# {'suname': 'Jafarov', 'name': 'Elbek', 'age': 58, 'phone_number': '+99893 1234567'}
# {'suname': 'Jafarov', 'name': 'Elbek', 'age': 58, 'phone_number': '+99893 1234567'}
# {'suname': 'Jafarov', 'name': 'Elbek', 'age': 29, 'phone_number': '+99893 1284521'}

# %%
query = {"suname":"Sirojiddinov"}

for value in kolleksiya.find(query, {"_id":0, "suname":1, "phone_number":1}): # ko'rsatishimiz kerak bo'lgan qiymatga 1 ni beramiz
    print(value)
# Out:
# {'suname': 'Sirojiddinov', 'phone_number': '+99890 4269578'}
# {'suname': 'Sirojiddinov', 'phone_number': '+99890 4269578'}

# %% [markdown]
# # <center> $gt

# %%
query = {"name":{"$gt":"K"}} # bu orqali biz birinchi bo'lib K harfidan boshlanadigan keyin esa alfavit bo'yicha undan keyin keladigan harflar
# bo'yicha qidirishni amalga oshiramiz
# Oddiyroq aytadigan bo'lsak alfavit bo'yicha K harfi va undan keyingi harflardan boshlanadigan name larni topib beradi

for value in kolleksiya.find(query):
    print(value)
# Bizning collectionimizda Elbek, Asal degan name lar bor edi
# pastga e'tbor bersangiz ular chiqmagan, chunki alfavit bo'yicha ular K harfidan oldin keladi, biz esa K harfi va undan keyin turuvchi harflar 
# bo'yicha qidiramiz
# Out:
# {'_id': 2, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 4, 'suname': 'Yuldoshev', 'name': 'Kamron', 'age': 28, 'phone_number': '+99890 6932541'}
# {'_id': 5, 'suname': 'Yuldosheva', 'name': 'Shaxzoda', 'age': 24, 'phone_number': '+99899 2593614'}
# {'_id': 6, 'suname': 'Jafarov', 'name': 'Malik', 'age': 22, 'phone_number': '+99899 1482536'}
# {'_id': 7, 'suname': 'Jafarov', 'name': 'Xushnud', 'age': 26, 'phone_number': '+99899 9623514'}
# {'_id': 11, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 13, 'suname': 'Yuldoshev', 'name': 'Kamron', 'age': 28, 'phone_number': '+99890 6932541'}
# {'_id': 14, 'suname': 'Yuldosheva', 'name': 'Shaxzoda', 'age': 24, 'phone_number': '+99899 2593614'}
# {'_id': 15, 'suname': 'Jafarov', 'name': 'Malik', 'age': 22, 'phone_number': '+99899 1482536'}
# {'_id': 16, 'suname': 'Jafarov', 'name': 'Xushnud', 'age': 26, 'phone_number': '+99899 9623514'}
# ...

# %%
query = {"name":{"$gt":"Kamron"}}

for value in kolleksiya.find(query):
    print(value)
    
# E'tibor bering hozir Kamron name ga ega bo'lgan dokuent chiqmagan chunki, $gt berilgan simvoldan keyingilarini qdiradi
# "$gt":"Kamron" berdik va u undan keyingilarini qidirishni boshlaydi
# Out:
# {'_id': 2, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 5, 'suname': 'Yuldosheva', 'name': 'Shaxzoda', 'age': 24, 'phone_number': '+99899 2593614'}
# {'_id': 6, 'suname': 'Jafarov', 'name': 'Malik', 'age': 22, 'phone_number': '+99899 1482536'}
# {'_id': 7, 'suname': 'Jafarov', 'name': 'Xushnud', 'age': 26, 'phone_number': '+99899 9623514'}
# {'_id': 11, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 14, 'suname': 'Yuldosheva', 'name': 'Shaxzoda', 'age': 24, 'phone_number': '+99899 2593614'}
# {'_id': 15, 'suname': 'Jafarov', 'name': 'Malik', 'age': 22, 'phone_number': '+99899 1482536'}
# {'_id': 16, 'suname': 'Jafarov', 'name': 'Xushnud', 'age': 26, 'phone_number': '+99899 9623514'}
# {'_id': 20, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99890 9876543'}

# %%
query = {"age":{"$gt":28}} # bu yerdan biz 28 yoshdan kattalarni qidiramiz

for value in kolleksiya.find(query):
    print(value)
# 28 yoshni o'zi ham chiqmaydi
# Out:
# {'_id': 1, 'suname': 'Jafarov', 'name': 'Elbek', 'age': 58, 'phone_number': '+99893 1234567'}
# {'_id': 2, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 3, 'suname': 'Sirojiddinova', 'name': 'Asal', 'age': 30, 'phone_number': '+99899 5463217'}
# {'_id': 10, 'suname': 'Jafarov', 'name': 'Elbek', 'age': 58, 'phone_number': '+99893 1234567'}
# {'_id': 11, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 12, 'suname': 'Sirojiddinova', 'name': 'Asal', 'age': 30, 'phone_number': '+99899 5463217'}
# {'_id': ObjectId('66375131c8bdeb09246a0abd'), 'suname': 'Bozorboyev', 'name': 'Dilshod', 'age': 50, 'phone_number': '+99899 1286543'}
# {'_id': 19, 'suname': 'Jafarov', 'name': 'Elbek', 'age': 29, 'phone_number': '+99893 1284521'}
# {'_id': 20, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99890 9876543'}
# ...

# %% [markdown]
# ## <center> $gt ni asosan sonlik qiymatlarda ishlatganimiz yaxshi

# %% [markdown]
# # <center> $regex

# %%
query = {"name":{"$regex":"K"}} # $gt dan farqli olaroq $regex faqt K qatnashgan dokumentlarni topadi. K harfi so'zni o'rtasida kelsa ham topadi

for value in kolleksiya.find(query):
    print(value)
# Out:
# {'_id': 4, 'suname': 'Yuldoshev', 'name': 'Kamron', 'age': 28, 'phone_number': '+99890 6932541'}
# {'_id': 13, 'suname': 'Yuldoshev', 'name': 'Kamron', 'age': 28, 'phone_number': '+99890 6932541'}

# %%
query = {"name":{"$regex":"i"}} # $ i harfi qatnashgan hamma dokumentlarni topadi

for value in kolleksiya.find(query):
    print(value)
# Out:
# {'_id': 2, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 6, 'suname': 'Jafarov', 'name': 'Malik', 'age': 22, 'phone_number': '+99899 1482536'}
# {'_id': 9, 'suname': 'Sirojiddinov', 'name': 'Alibek', 'age': 26, 'phone_number': '+99890 4269578'}
# {'_id': 11, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 15, 'suname': 'Jafarov', 'name': 'Malik', 'age': 22, 'phone_number': '+99899 1482536'}
# {'_id': 18, 'suname': 'Sirojiddinov', 'name': 'Alibek', 'age': 26, 'phone_number': '+99890 4269578'}
# {'_id': ObjectId('66375131c8bdeb09246a0abd'), 'suname': 'Bozorboyev', 'name': 'Dilshod', 'age': 50, 'phone_number': '+99899 1286543'}
# {'_id': 20, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99890 9876543'}
# {'_id': 21, 'suname': 'Asilbekova', 'name': 'Diyora', 'age': 22, 'phone_number': '+9988 5552296'}
# ...

# %%
query = {"name":{"$regex":"Alibek"}} # $ i harfi qatnashgan hamma dokumentlarni topadi

for value in kolleksiya.find(query):
    print(value)
# Out:
# {'_id': 9, 'suname': 'Sirojiddinov', 'name': 'Alibek', 'age': 26, 'phone_number': '+99890 4269578'}
# {'_id': 18, 'suname': 'Sirojiddinov', 'name': 'Alibek', 'age': 26, 'phone_number': '+99890 4269578'}

# %%
query = {"age":{"$regex":54}} # $regex parametr sifatida satr qabul qiladi, age bo'lsa bizda int

for value in kolleksiya.find(query):
    print(value)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[70], line 3
#       1 query = {"age":{"$regex":54}} # $ regex asosan parametr sifatida star kutadi, agar biz
# ----> 3 for value in kolleksiya.find(query):
#       4     print(value)
#
# File D:\IT\Python\YOLO\yolo\lib\site-packages\pymongo\cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File D:\IT\Python\YOLO\yolo\lib\site-packages\pymongo\cursor.py:1181, in Cursor._refresh(self)
#    1159         raise InvalidOperation(
#    1160             "Passing a 'hint' is required when using the min/max query"
#    1161             " option to ensure the query utilizes the correct index"
#    1162         )
#    1163     q = self._query_class(
# ...

# %% [markdown]
# ## <center> $regex parametr sifatida satr qabul qiladi, int va boshqa qiymatlarni qabul qilmaydi

# %% [markdown]
# ## <center> `&gt ni sonli qiymatlarda ishlatsak yaxshiroq bo'ladi(lekin satrli qiymatlarda ham ishlatishimiz mumkin). $regex ni esa faqat satrli qiymatlarda ishlatishimiz mumkin($regex argument sifatida son qabul qilmaydi)`

# %% [markdown]
# ## <center> find_one

# %%
kolleksiya.find_one({})# ichiga hech qanday argument bermasak 1-dokumentni chiqaradi
# Out:
# {'_id': 1,
#  'suname': 'Jafarov',
#  'name': 'Elbek',
#  'age': 58,
#  'phone_number': '+99893 1234567'}

# %%
result = kolleksiya.find_one({"name":"Elbek"})
result
# Elbek ismlik document 3 ta edi find_one orqali biz birinchi uchraganini chiqaramiz
# Out:
# {'_id': 1,
#  'suname': 'Jafarov',
#  'name': 'Elbek',
#  'age': 58,
#  'phone_number': '+99893 1234567'}

# %% [markdown]
# ## <center> limit

# %%
for value in kolleksiya.find().limit(6): #Birinchi 6 ta dokumentni chiqarish
    print(value)
# Out:
# {'_id': 1, 'suname': 'Jafarov', 'name': 'Elbek', 'age': 58, 'phone_number': '+99893 1234567'}
# {'_id': 2, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 3, 'suname': 'Sirojiddinova', 'name': 'Asal', 'age': 30, 'phone_number': '+99899 5463217'}
# {'_id': 4, 'suname': 'Yuldoshev', 'name': 'Kamron', 'age': 28, 'phone_number': '+99890 6932541'}
# {'_id': 5, 'suname': 'Yuldosheva', 'name': 'Shaxzoda', 'age': 24, 'phone_number': '+99899 2593614'}
# {'_id': 6, 'suname': 'Jafarov', 'name': 'Malik', 'age': 22, 'phone_number': '+99899 1482536'}

# %%
query = {"suname":{"$regex":"Y"}}

for value in kolleksiya.find(query).limit(3): # boshidan 3 ta topgan dokumenti chiqaradi
    print(value)
# Out:
# {'_id': 2, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 4, 'suname': 'Yuldoshev', 'name': 'Kamron', 'age': 28, 'phone_number': '+99890 6932541'}
# {'_id': 5, 'suname': 'Yuldosheva', 'name': 'Shaxzoda', 'age': 24, 'phone_number': '+99899 2593614'}

# %% [markdown]
# ## <center> sort

# %%
for value in kolleksiya.find().sort("name",1): #sort("name", 1) orqali alfavit bo'yicha sort qilamiz
    print(value)
# Lekin e'tibor bering
# sortlashda agar bizda qaysidur dokumentda kerakli kalit bo'lmasa(masalan name) shu dokumentlar birinchi chiqariladi
# undan keyin esa kalit bo'yicha sort qilib chiqariladi
# Out:
# {'_id': 24, 'laptop_model': 'Hp Pavilion Gaming', 'cpu': 'Amd Ryzen', 'gpu': 'GeForce GTX 1650 Ti'}
# {'_id': 25, 'phone_model': 'iphone 15', 'cpu': '16 Bionic', 'dsplay': 'Liquid Retina XDR'}
# {'_id': 26, 'car_model': 'Mersedes Benz GLA', 'engine_capacity': 1595, 'transmission': 'Manual transmission', 'Number_of_seats': 5}
# {'_id': 9, 'suname': 'Sirojiddinov', 'name': 'Alibek', 'age': 26, 'phone_number': '+99890 4269578'}
# {'_id': 18, 'suname': 'Sirojiddinov', 'name': 'Alibek', 'age': 26, 'phone_number': '+99890 4269578'}
# {'_id': 3, 'suname': 'Sirojiddinova', 'name': 'Asal', 'age': 30, 'phone_number': '+99899 5463217'}
# {'_id': 12, 'suname': 'Sirojiddinova', 'name': 'Asal', 'age': 30, 'phone_number': '+99899 5463217'}
# {'_id': 8, 'suname': 'Yuldoshev', 'name': 'Bobur', 'age': 28, 'phone_number': '+99894 2589641'}
# {'_id': 17, 'suname': 'Yuldoshev', 'name': 'Bobur', 'age': 28, 'phone_number': '+99894 2589641'}
# ...

# %%
for value in kolleksiya.find().sort("name", -1): #sort("name", -1) orqali alfavit bo'yicha teskari sort qilamiz
    print(value)
# Out:
# {'_id': 2, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 11, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99893 9876543'}
# {'_id': 20, 'suname': 'Yuldoshev', 'name': 'Zohid', 'age': 57, 'phone_number': '+99890 9876543'}
# {'_id': 7, 'suname': 'Jafarov', 'name': 'Xushnud', 'age': 26, 'phone_number': '+99899 9623514'}
# {'_id': 16, 'suname': 'Jafarov', 'name': 'Xushnud', 'age': 26, 'phone_number': '+99899 9623514'}
# {'_id': 5, 'suname': 'Yuldosheva', 'name': 'Shaxzoda', 'age': 24, 'phone_number': '+99899 2593614'}
# {'_id': 14, 'suname': 'Yuldosheva', 'name': 'Shaxzoda', 'age': 24, 'phone_number': '+99899 2593614'}
# {'_id': 6, 'suname': 'Jafarov', 'name': 'Malik', 'age': 22, 'phone_number': '+99899 1482536'}
# {'_id': 15, 'suname': 'Jafarov', 'name': 'Malik', 'age': 22, 'phone_number': '+99899 1482536'}
# {'_id': 4, 'suname': 'Yuldoshev', 'name': 'Kamron', 'age': 28, 'phone_number': '+99890 6932541'}
# ...

# %% [markdown]
# # <center> <h1> 👨‍💻   🚀
