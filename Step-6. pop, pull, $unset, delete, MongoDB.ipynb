# %% [markdown]
# # <center> <h1>  💾 🧑‍💻 🗃️

# %% [markdown]
# <center>
#
# # ![MongoDB_Logo.jpg](attachment:c2359e32-8944-4cf3-8a94-99467c84d68f.jpg)

# %%
import pymongo

# %%
# 1 - bo'lib saytdan Cluster ga ulanamiz
client = pymongo.MongoClient("mongodb+srv://userName:password@cluster0.0ib3cab.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
#client
# userName - o'zingizning username ni yozasiz
# password -  o'zingizning parolni yozasiz

# %%
# database
db = client.test
#db

# %%
kolleksiya = db.number_password
#kolleksiya

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 0, 'name': 'test0', 'password': 987654321, 'age': 1}
# {'_id': 1, 'name': 'test1', 'password': 987654321, 'balance': 1100, 'age': 2}
# {'_id': 2, 'name': 'test2', 'password': 987654321, 'age': 3}
# {'_id': 3, 'name': 'new_test3', 'password': 987654321, 'age': 4}
# {'_id': 4, 'name': 'test4', 'password': 987654321, 'age': 5}
# {'_id': 5, 'name': 'test5', 'password': 987654321, 'age': 6}
# {'_id': 6, 'name': 'test6', 'password': 987654321, 'age': 7}
# {'_id': 7, 'name': 'test7', 'password': 987654321, 'age': 8}
# {'_id': 8, 'name': 'test8', 'password': 987654321, 'age': 9}
# {'_id': 9, 'name': 'test9', 'password': 987654321, 'age': 10}
# {'_id': 10, 'name': 'test10', 'password': 987654321, 'age': 11}
# {'_id': 11, 'name': 'test11', 'password': 987654321, 'age': 12}
# {'_id': 12, 'name': 'test12', 'password': 987654321, 'age': 13}
# {'_id': 13, 'name': 'test13', 'password': 987654321, 'age': 14}
# {'_id': 14, 'name': 'test14', 'password': 987654321, 'age': 15}
# ...

# %%
# 1 ta dokumentga array qo'shib  olamiz
current = {"_id":1}
new_data = {"$set":{"edu":["Tatu","NU"]}}

kolleksiya.update_one(current, new_data)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714917233, 3), 't': 12}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714917233, 3), 'signature': {'hash': b'\xda\x92:%\x8f\xa6\x93\x95\xe1\x00*\xa8/$\x06\x97\xbe2eB', 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714917233, 3), 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:f7bce136-bfd1-4bc4-892c-415df9f08d8e.png)

# %% [markdown]
# ## <center> pop - elmentni index bo'yicha o'chiradi

# %%
# Arrayning 1-elementini o'chirish. POP
current = {"_id":1}
new_data = {"$pop":{"edu":1}}

kolleksiya.update_one(current, new_data)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714917398, 3), 't': 12}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714917398, 3), 'signature': {'hash': b'\xb0\xeb#SK\xd7EO^B\x16\x0b\x9b\x97\xb88}rK\x15', 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714917398, 3), 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:f2f86101-15d9-4ed8-9855-61a24c240b0e.png)

# %% [markdown]
# ## <center> pull - elementni nomi bo'yicha o'chiradi

# %%
# Arrayning 0-elementini o'chirish. PULL
current = {"_id":1}
new_data = {"$pull":{"edu":"Tatu"}}

kolleksiya.update_one(current, new_data)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714917557, 1), 't': 12}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714917557, 1), 'signature': {'hash': b'\xba)=\xd2\xd1\xc1\xb7`?\x7f\x13\xa3\xbe0\xa2\x868\x12\xdb\x11', 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714917557, 1), 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:8c59ac45-2803-4834-927e-d7bc38b594a7.png)

# %% [markdown]
# ## <center> $unset - yangilash, dokumentdan elemntlarni o'chirish uchun ishlatiladi

# %%
# Arrayni o'zini ham o'chirb tashlaymiz
kolleksiya.update_one({"edu":[]}, {"$unset":{"edu":""}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714917991, 1), 't': 12}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714917991, 1), 'signature': {'hash': b"\x8a,\x18\xdc\xe3>bQ\x10\xa0\xe8\x1c\xcd9\xed\xb2\xc4'.c", 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714917991, 1), 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:b4820166-07ac-4653-b774-00df5ef02333.png)

# %% [markdown]
# ##  <center> Delete - dokumentlarni o'chiramiz

# %%
kolleksiya.delete_one({"_id":0})
# 0-dokumentni o'chiradi
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714918285, 3), 't': 12}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714918285, 3), 'signature': {'hash': b'e\x00\x10_\x9e(\x18\x98J\xe0|\xa0\x12\x1cx\xa6\xe6\x9b\x9f\xcf', 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714918285, 3)}, acknowledged=True)

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 1, 'name': 'test1', 'password': 987654321, 'balance': 1100, 'age': 2}
# {'_id': 2, 'name': 'test2', 'password': 987654321, 'age': 3}
# {'_id': 3, 'name': 'new_test3', 'password': 987654321, 'age': 4}
# {'_id': 4, 'name': 'test4', 'password': 987654321, 'age': 5}
# {'_id': 5, 'name': 'test5', 'password': 987654321, 'age': 6}
# {'_id': 6, 'name': 'test6', 'password': 987654321, 'age': 7}
# {'_id': 7, 'name': 'test7', 'password': 987654321, 'age': 8}
# {'_id': 8, 'name': 'test8', 'password': 987654321, 'age': 9}
# {'_id': 9, 'name': 'test9', 'password': 987654321, 'age': 10}
# {'_id': 10, 'name': 'test10', 'password': 987654321, 'age': 11}
# {'_id': 11, 'name': 'test11', 'password': 987654321, 'age': 12}
# {'_id': 12, 'name': 'test12', 'password': 987654321, 'age': 13}
# {'_id': 13, 'name': 'test13', 'password': 987654321, 'age': 14}
# {'_id': 14, 'name': 'test14', 'password': 987654321, 'age': 15}
# {'_id': 15, 'name': 'test15', 'password': 987654321, 'age': 16}
# ...

# %%
kolleksiya.insert_one({'_id': 22, 'name': 'test2', 'password': 987654321, 'age': 3})
kolleksiya.insert_one({'_id': 23, 'name': 'test2', 'password': 987654321, 'age': 3})
kolleksiya.insert_one({'_id': 24, 'name': 'test2', 'password': 987654321, 'age': 3})
# 3 ta yangi dokumnet qoshib oldik
# Out:
# InsertOneResult(24, acknowledged=True)

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 1, 'name': 'test1', 'password': 987654321, 'balance': 1100, 'age': 2}
# {'_id': 2, 'name': 'test2', 'password': 987654321, 'age': 3}
# {'_id': 3, 'name': 'new_test3', 'password': 987654321, 'age': 4}
# {'_id': 4, 'name': 'test4', 'password': 987654321, 'age': 5}
# {'_id': 5, 'name': 'test5', 'password': 987654321, 'age': 6}
# {'_id': 6, 'name': 'test6', 'password': 987654321, 'age': 7}
# {'_id': 7, 'name': 'test7', 'password': 987654321, 'age': 8}
# {'_id': 8, 'name': 'test8', 'password': 987654321, 'age': 9}
# {'_id': 9, 'name': 'test9', 'password': 987654321, 'age': 10}
# {'_id': 10, 'name': 'test10', 'password': 987654321, 'age': 11}
# {'_id': 11, 'name': 'test11', 'password': 987654321, 'age': 12}
# {'_id': 12, 'name': 'test12', 'password': 987654321, 'age': 13}
# {'_id': 13, 'name': 'test13', 'password': 987654321, 'age': 14}
# {'_id': 14, 'name': 'test14', 'password': 987654321, 'age': 15}
# {'_id': 15, 'name': 'test15', 'password': 987654321, 'age': 16}
# ...

# %%
# $regex ishlatgan holda name=test2 larni hammasini o'chirib tashlaymiz
query = {"name":{"$regex":"test2"}}

kolleksiya.delete_many(query)
# Out:
# DeleteResult({'n': 4, 'electionId': ObjectId('7fffffff000000000000000c'), 'opTime': {'ts': Timestamp(1714918447, 2), 't': 12}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1714918447, 6), 'signature': {'hash': b'\xf7Q?\xdc\xe9\xbbh=\x02\x1d\xd33\x01\xc0\x06\x8eR\xe1\x0b\xc7', 'keyId': 7323552270614790150}}, 'operationTime': Timestamp(1714918447, 2)}, acknowledged=True)

# %%
for value in kolleksiya.find():
    print(value)
# Out:
# {'_id': 1, 'name': 'test1', 'password': 987654321, 'balance': 1100, 'age': 2}
# {'_id': 3, 'name': 'new_test3', 'password': 987654321, 'age': 4}
# {'_id': 4, 'name': 'test4', 'password': 987654321, 'age': 5}
# {'_id': 5, 'name': 'test5', 'password': 987654321, 'age': 6}
# {'_id': 6, 'name': 'test6', 'password': 987654321, 'age': 7}
# {'_id': 7, 'name': 'test7', 'password': 987654321, 'age': 8}
# {'_id': 8, 'name': 'test8', 'password': 987654321, 'age': 9}
# {'_id': 9, 'name': 'test9', 'password': 987654321, 'age': 10}
# {'_id': 10, 'name': 'test10', 'password': 987654321, 'age': 11}
# {'_id': 11, 'name': 'test11', 'password': 987654321, 'age': 12}
# {'_id': 12, 'name': 'test12', 'password': 987654321, 'age': 13}
# {'_id': 13, 'name': 'test13', 'password': 987654321, 'age': 14}
# {'_id': 14, 'name': 'test14', 'password': 987654321, 'age': 15}
# {'_id': 15, 'name': 'test15', 'password': 987654321, 'age': 16}
# {'_id': 16, 'name': 'test16', 'password': 987654321, 'age': 17}
# ...

# %%
# kollekiyadagi hamma dokumentni o'chirmoqchi bolsak
# kolleksiya.delet_many({})

# %% [markdown]
# # <center> <h1> 👨‍💻   🚀
